# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)

# Adds absolute path as reference
sys.path.append("D:/Oxford Engineering Third Year/B1 Engineering Computation/b1-coding-practical-mt24")
# Out:
# ['C:\\Users\\Christopher Ivan B\\.conda\\envs\\B1-W12-Oxon\\python313.zip', 'C:\\Users\\Christopher Ivan B\\.conda\\envs\\B1-W12-Oxon\\DLLs', 'C:\\Users\\Christopher Ivan B\\.conda\\envs\\B1-W12-Oxon\\Lib', 'C:\\Users\\Christopher Ivan B\\.conda\\envs\\B1-W12-Oxon', '', 'C:\\Users\\Christopher Ivan B\\.conda\\envs\\B1-W12-Oxon\\Lib\\site-packages', 'C:\\Users\\Christopher Ivan B\\.conda\\envs\\B1-W12-Oxon\\Lib\\site-packages\\win32', 'C:\\Users\\Christopher Ivan B\\.conda\\envs\\B1-W12-Oxon\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\Christopher Ivan B\\.conda\\envs\\B1-W12-Oxon\\Lib\\site-packages\\Pythonwin', 'D:/Oxford Engineering Third Year/B1 Engineering Computation/b1-coding-practical-mt24']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission.dynamic import *

sub = Submarine()
controller = Controller(0.15, 0.6)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("../data/mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only length-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 9
#       6 closed_loop = ClosedLoop(sub, controller)
#       7 mission = Mission.from_csv("../data/mission.csv") # You must implement this method in the Mission class
# ----> 9 trajectory = closed_loop.simulate_with_random_disturbances(mission)
#      10 trajectory.plot_completed_mission(mission)
#
# File D:\Oxford Engineering Third Year/B1 Engineering Computation/b1-coding-practical-mt24\uuv_mission\dynamic.py:126, in ClosedLoop.simulate_with_random_disturbances(self, mission, variance)
# ...
